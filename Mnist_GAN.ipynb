# %% [markdown]
# <a href="https://colab.research.google.com/github/mahdiheidari721/AI-Internship/blob/master/Mnist_GAN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import numpy as np
import math
import sys
from time import time
import torchvision.transforms as transforms
from torchvision.utils import save_image
from torch.utils.data import DataLoader
from torchvision import datasets
from torch.autograd import Variable
import torch.nn as nn
import torch.nn.functional as F
import torch
import torchvision
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
 
os.makedirs("images", exist_ok=True)
 
class Opt(object):
    dim = 10
    n_epochs = 200
    batch_size = dim*dim
    lr = 0.0002
    b1 = 0.5
    b2 = 0.999
    n_cpu = 1
    latent_dim = 100
    img_size = 28
    channels = 1
    sample_interval = 400
opt = Opt()  
 
img_shape = (opt.channels, opt.img_size, opt.img_size)
 
cuda = True if torch.cuda.is_available() else False
 
class Generator(nn.Module):
    def __init__(self):
        super(Generator, self).__init__()
        def block(in_feat, out_feat, normalize=True):
            layers = [nn.Linear(in_feat, out_feat)]
            if normalize:
                layers.append(nn.BatchNorm1d(out_feat, 0.8))
            layers.append(nn.LeakyReLU(0.2, inplace=True))
            return layers
        self.model = nn.Sequential(
            *block(opt.latent_dim, 128, normalize=False),
            *block(128, 256),
            *block(256, 512),
            *block(512, 1024),
            nn.Linear(1024, int(np.prod(img_shape))),
            nn.Tanh()
        )
    def forward(self, z):
        img = self.model(z)
        img = img.view(img.size(0), *img_shape)
        return img
 
class Discriminator(nn.Module):
    def __init__(self):
        super(Discriminator, self).__init__()
        self.model = nn.Sequential(
            nn.Linear(int(np.prod(img_shape)), 512),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Linear(512, 256),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Linear(256, 1),
            nn.Sigmoid(),
        )
    def forward(self, img):
        img_flat = img.view(img.size(0), -1)
        validity = self.model(img_flat)
        return validity
 
bce_loss = torch.nn.BCELoss()
generator = Generator()
discriminator = Discriminator()
 
if cuda:
    generator.cuda()
    discriminator.cuda()
    bce_loss.cuda()
 
# Configure data loader
os.makedirs("../../data/mnist", exist_ok=True)
dataloader = torch.utils.data.DataLoader(
    datasets.MNIST(
        "../../data/mnist",
        train=True,
        download=True,
        transform=transforms.Compose([transforms.ToTensor(), transforms.Normalize([0.5], [0.5])]),
    ),
    batch_size=opt.batch_size,
    shuffle=True,
)
 
# Optimizers
generator_optimizer = torch.optim.Adam(generator.parameters(), lr=opt.lr, betas=(opt.b1, opt.b2))
discriminator_optimizer = torch.optim.Adam(discriminator.parameters(), lr=opt.lr, betas=(opt.b1, opt.b2))
 
Tensor = torch.cuda.FloatTensor if cuda else torch.FloatTensor
 
# ----------
#  Training
# ----------
 
saved_imgs = []
for epoch in range(opt.n_epochs):
    print('Epoch ' + str(epoch) + ' training...' , end=' ')
    start = time()
    for i, (imgs, _) in enumerate(dataloader):
        real = Variable(Tensor(imgs.size(0), 1).fill_(1.0), requires_grad=False)
        fake = Variable(Tensor(imgs.size(0), 1).fill_(0.0), requires_grad=False)
        real_imgs = Variable(imgs.type(Tensor))
        #  train Generator
        generator_optimizer.zero_grad()
        # sample noise as generator input
        z = Variable(Tensor(np.random.normal(0, 1, (imgs.shape[0], opt.latent_dim))))
        # generate a batch of images
        gen_imgs = generator(z)
        # loss measures generator's ability to fool the discriminator:
        # for the generated images, the generator wants the discriminator to think they're real (1)
        # so if the discriminator(gen_imgs) == real == 1, then the generator is doing a good job, there is no loss
        generator_loss = bce_loss(discriminator(gen_imgs), real)
        generator_loss.backward()
        generator_optimizer.step()
        # train Discriminator
        discriminator_optimizer.zero_grad()
        # loss measure discriminator's ability to classify real from generated samples:
        real_loss = bce_loss(discriminator(real_imgs),         real)
        fake_loss = bce_loss(discriminator(gen_imgs.detach()), fake)
        discriminator_loss = (real_loss + fake_loss) / 2
        discriminator_loss.backward()
        discriminator_optimizer.step()
        batches_done = epoch * len(dataloader) + i
    end = time()
    elapsed = end - start
    print('done, took %.1f seconds.' % elapsed)
    grid = torchvision.utils.make_grid(gen_imgs.data.cpu(), nrow=opt.dim)
    img = (np.transpose(grid.detach().numpy(), (1, 2 ,0)) * 255).astype(np.uint8)
    saved_imgs.append(img)
# Out:
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz to ../../data/mnist/MNIST/raw/train-images-idx3-ubyte.gz
#   0%|          | 0/9912422 [00:00<?, ?it/s]
# Extracting ../../data/mnist/MNIST/raw/train-images-idx3-ubyte.gz to ../../data/mnist/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz to ../../data/mnist/MNIST/raw/train-labels-idx1-ubyte.gz
#   0%|          | 0/28881 [00:00<?, ?it/s]
# Extracting ../../data/mnist/MNIST/raw/train-labels-idx1-ubyte.gz to ../../data/mnist/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz to ../../data/mnist/MNIST/raw/t10k-images-idx3-ubyte.gz
#   0%|          | 0/1648877 [00:00<?, ?it/s]
# Extracting ../../data/mnist/MNIST/raw/t10k-images-idx3-ubyte.gz to ../../data/mnist/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz to ../../data/mnist/MNIST/raw/t10k-labels-idx1-ubyte.gz
#   0%|          | 0/4542 [00:00<?, ?it/s]
# Extracting ../../data/mnist/MNIST/raw/t10k-labels-idx1-ubyte.gz to ../../data/mnist/MNIST/raw
#
# Epoch 0 training... done, took 20.4 seconds.
# Epoch 1 training... done, took 12.9 seconds.
# Epoch 2 training... done, took 12.8 seconds.
# Epoch 3 training... done, took 12.8 seconds.
# Epoch 4 training... done, took 13.9 seconds.
# Epoch 5 training... done, took 12.9 seconds.
# Epoch 6 training... done, took 13.5 seconds.
# Epoch 7 training... done, took 12.9 seconds.
# Epoch 8 training... done, took 12.8 seconds.
# Epoch 9 training... done, took 12.9 seconds.
# Epoch 10 training... done, took 12.9 seconds.
# Epoch 11 training... done, took 12.9 seconds.
# Epoch 12 training... done, took 12.8 seconds.
# Epoch 13 training... done, took 12.7 seconds.
# Epoch 14 training... done, took 12.7 seconds.
# Epoch 15 training... done, took 12.8 seconds.
# Epoch 16 training... done, took 13.4 seconds.
# Epoch 17 training... done, took 13.1 seconds.
# Epoch 18 training... done, took 12.9 seconds.
# Epoch 19 training... done, took 12.8 seconds.
# Epoch 20 training... done, took 12.8 seconds.
# Epoch 21 training... done, took 13.0 seconds.
# Epoch 22 training... done, took 13.1 seconds.
# Epoch 23 training... done, took 13.1 seconds.
# Epoch 24 training... done, took 13.1 seconds.
# Epoch 25 training... done, took 13.0 seconds.
# Epoch 26 training... done, took 13.4 seconds.
# Epoch 27 training... done, took 13.8 seconds.
# Epoch 28 training... done, took 13.2 seconds.
# Epoch 29 training... done, took 13.2 seconds.
# Epoch 30 training... done, took 13.2 seconds.
# Epoch 31 training... done, took 13.6 seconds.
# Epoch 32 training... done, took 13.7 seconds.
# Epoch 33 training... done, took 13.6 seconds.
# Epoch 34 training... done, took 13.6 seconds.
# Epoch 35 training... done, took 13.1 seconds.
# Epoch 36 training... done, took 12.9 seconds.
# Epoch 37 training... done, took 12.7 seconds.
# Epoch 38 training... done, took 13.5 seconds.
# Epoch 39 training... done, took 12.8 seconds.
# Epoch 40 training... done, took 12.7 seconds.
# Epoch 41 training... done, took 12.8 seconds.
# Epoch 42 training... done, took 12.8 seconds.
# Epoch 43 training... done, took 12.8 seconds.
# Epoch 44 training... done, took 12.8 seconds.
# Epoch 45 training... done, took 12.8 seconds.
# Epoch 46 training... done, took 13.0 seconds.
# Epoch 47 training... done, took 12.8 seconds.
# Epoch 48 training... done, took 13.5 seconds.
# Epoch 49 training... done, took 12.9 seconds.
# Epoch 50 training... done, took 12.8 seconds.
# Epoch 51 training... done, took 12.8 seconds.
# Epoch 52 training... done, took 12.8 seconds.
# Epoch 53 training... done, took 12.8 seconds.
# Epoch 54 training... done, took 13.0 seconds.
# Epoch 55 training... done, took 12.8 seconds.
# Epoch 56 training... done, took 12.9 seconds.
# Epoch 57 training... done, took 12.9 seconds.
# Epoch 58 training... done, took 13.0 seconds.
# Epoch 59 training... done, took 13.5 seconds.
# Epoch 60 training... done, took 13.2 seconds.
# Epoch 61 training... done, took 12.9 seconds.
# Epoch 62 training... done, took 12.8 seconds.
# Epoch 63 training... done, took 12.8 seconds.
# Epoch 64 training... done, took 13.0 seconds.
# Epoch 65 training... done, took 12.9 seconds.
# Epoch 66 training... done, took 12.9 seconds.
# Epoch 67 training... done, took 12.9 seconds.
# Epoch 68 training... done, took 12.9 seconds.
# Epoch 69 training... done, took 13.0 seconds.
# Epoch 70 training... done, took 13.6 seconds.
# Epoch 71 training... done, took 12.9 seconds.
# Epoch 72 training... done, took 12.9 seconds.
# Epoch 73 training... done, took 12.9 seconds.
# Epoch 74 training... done, took 12.7 seconds.
# Epoch 75 training... done, took 12.7 seconds.
# Epoch 76 training... done, took 12.9 seconds.
# Epoch 77 training... done, took 12.7 seconds.
# Epoch 78 training... done, took 12.9 seconds.
# Epoch 79 training... done, took 12.9 seconds.
# Epoch 80 training... done, took 12.8 seconds.
# Epoch 81 training... done, took 13.4 seconds.
# Epoch 82 training... done, took 12.8 seconds.
# Epoch 83 training... done, took 12.8 seconds.
# Epoch 84 training... done, took 12.8 seconds.
# Epoch 85 training... done, took 12.9 seconds.
# Epoch 86 training... done, took 13.0 seconds.
# Epoch 87 training... done, took 12.9 seconds.
# Epoch 88 training... done, took 13.0 seconds.
# Epoch 89 training... done, took 12.7 seconds.
# Epoch 90 training... done, took 13.0 seconds.
# Epoch 91 training... done, took 12.9 seconds.
# Epoch 92 training... done, took 13.7 seconds.
# Epoch 93 training... done, took 13.0 seconds.
# Epoch 94 training... done, took 13.3 seconds.
# Epoch 95 training... done, took 13.1 seconds.
# Epoch 96 training... done, took 12.9 seconds.
# Epoch 97 training... done, took 12.8 seconds.
# Epoch 98 training... done, took 12.9 seconds.
# Epoch 99 training... done, took 13.0 seconds.
# Epoch 100 training... done, took 13.1 seconds.
# Epoch 101 training... done, took 13.1 seconds.
# Epoch 102 training... done, took 13.2 seconds.
# Epoch 103 training... done, took 13.8 seconds.
# Epoch 104 training... done, took 13.3 seconds.
# Epoch 105 training... done, took 13.2 seconds.
# Epoch 106 training... done, took 13.3 seconds.
# Epoch 107 training... done, took 13.1 seconds.
# Epoch 108 training... done, took 13.1 seconds.
# Epoch 109 training... done, took 13.1 seconds.
# Epoch 110 training... done, took 13.3 seconds.
# Epoch 111 training... done, took 13.1 seconds.
# Epoch 112 training... done, took 12.9 seconds.
# Epoch 113 training... done, took 13.0 seconds.
# Epoch 114 training... done, took 13.6 seconds.
# Epoch 115 training... done, took 13.0 seconds.
# Epoch 116 training... done, took 13.0 seconds.
# Epoch 117 training... done, took 13.1 seconds.
# Epoch 118 training... done, took 13.0 seconds.
# Epoch 119 training... done, took 13.0 seconds.
# Epoch 120 training... done, took 13.0 seconds.
# Epoch 121 training... done, took 12.7 seconds.
# Epoch 122 training... done, took 12.8 seconds.
# Epoch 123 training... done, took 12.7 seconds.
# Epoch 124 training... done, took 12.7 seconds.
# Epoch 125 training... done, took 13.2 seconds.
# Epoch 126 training... done, took 12.6 seconds.
# Epoch 127 training... done, took 12.6 seconds.
# Epoch 128 training... done, took 12.7 seconds.
# Epoch 129 training... done, took 12.8 seconds.
# Epoch 130 training... done, took 12.6 seconds.
# Epoch 131 training... done, took 12.6 seconds.
# Epoch 132 training... done, took 12.7 seconds.
# Epoch 133 training... done, took 12.6 seconds.
# Epoch 134 training... done, took 12.7 seconds.
# Epoch 135 training... done, took 12.7 seconds.
# Epoch 136 training... done, took 13.2 seconds.
# Epoch 137 training... done, took 12.6 seconds.
# Epoch 138 training... done, took 12.6 seconds.
# Epoch 139 training... done, took 12.6 seconds.
# Epoch 140 training... done, took 12.8 seconds.
# Epoch 141 training... done, took 12.9 seconds.
# Epoch 142 training... done, took 12.7 seconds.
# Epoch 143 training... done, took 12.7 seconds.
# Epoch 144 training... done, took 12.6 seconds.
# Epoch 145 training... done, took 12.6 seconds.
# Epoch 146 training... done, took 12.6 seconds.
# Epoch 147 training... done, took 13.3 seconds.
# Epoch 148 training... done, took 12.7 seconds.
# Epoch 149 training... done, took 12.6 seconds.
# Epoch 150 training... done, took 12.6 seconds.
# Epoch 151 training... done, took 12.7 seconds.
# Epoch 152 training... done, took 12.6 seconds.
# Epoch 153 training... done, took 12.6 seconds.
# Epoch 154 training... done, took 12.7 seconds.
# Epoch 155 training... done, took 12.7 seconds.
# Epoch 156 training... done, took 12.6 seconds.
# Epoch 157 training... done, took 12.6 seconds.
# Epoch 158 training... done, took 13.3 seconds.
# Epoch 159 training... done, took 12.7 seconds.
# Epoch 160 training... done, took 12.7 seconds.
# Epoch 161 training... done, took 12.8 seconds.
# Epoch 162 training... done, took 12.7 seconds.
# Epoch 163 training... done, took 12.7 seconds.
# Epoch 164 training... done, took 12.6 seconds.
# Epoch 165 training... done, took 12.7 seconds.
# Epoch 166 training... done, took 12.7 seconds.
# Epoch 167 training... done, took 12.8 seconds.
# Epoch 168 training... done, took 12.5 seconds.
# Epoch 169 training... done, took 13.1 seconds.
# Epoch 170 training... done, took 12.5 seconds.
# Epoch 171 training... done, took 12.5 seconds.
# Epoch 172 training... done, took 12.5 seconds.
# Epoch 173 training... done, took 12.7 seconds.
# Epoch 174 training... done, took 12.7 seconds.
# Epoch 175 training... done, took 12.6 seconds.
# Epoch 176 training... done, took 12.5 seconds.
# Epoch 177 training... done, took 12.6 seconds.
# Epoch 178 training... done, took 12.5 seconds.
# Epoch 179 training... done, took 12.6 seconds.
# Epoch 180 training... done, took 13.3 seconds.
# Epoch 181 training... done, took 12.5 seconds.
# Epoch 182 training... done, took 12.4 seconds.
# Epoch 183 training... done, took 12.5 seconds.
# Epoch 184 training... done, took 12.5 seconds.
# Epoch 185 training... done, took 12.4 seconds.
# Epoch 186 training... done, took 12.7 seconds.
# Epoch 187 training... done, took 12.5 seconds.
# Epoch 188 training... done, took 12.4 seconds.
# Epoch 189 training... done, took 12.5 seconds.
# Epoch 190 training... done, took 12.6 seconds.
# Epoch 191 training... done, took 13.3 seconds.
# Epoch 192 training... done, took 12.6 seconds.
# Epoch 193 training... done, took 12.6 seconds.
# Epoch 194 training... done, took 12.4 seconds.
# Epoch 195 training... done, took 12.6 seconds.
# Epoch 196 training... done, took 12.5 seconds.
# Epoch 197 training... done, took 12.5 seconds.
# Epoch 198 training... done, took 12.7 seconds.
# Epoch 199 training... done, took 12.7 seconds.

# %%
img_indexes = [0, 4, 9, 49, 99, 149, 199]
for i in img_indexes:
    plt.figure(figsize = (opt.dim, opt.dim))
    plt.imshow(saved_imgs[i], interpolation='nearest')
